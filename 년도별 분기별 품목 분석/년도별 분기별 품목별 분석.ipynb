# %% [markdown]
# ## 2018년도 분석

# %%
# 파이썬 표시 깨짐 방지 하는 문구
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False 
f_path = "C:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname = f_path).get_name()
rc('font', family=font_name)

import pandas as pd
import seaborn as sns
import plotly.express as px
# 파일들 불러오기
df5 = pd.read_csv('../data/2018.1분기.csv')
df6 = pd.read_csv('../data/2018.2분기.csv')
df7 = pd.read_csv('../data/2018.3분기.csv')
df8 = pd.read_csv('../data/2018.4분기.csv')

df5.sort_values(by='합계', ascending=False, inplace = True)

# 그래프 x라벨값들 순서 통일
order_df5 = df5['품목'].unique()
order_df6 = df5['품목'].unique()
order_df7 = df5['품목'].unique()
order_df8 = df5['품목'].unique()

# 그래프 색상 설정
custom_palette = sns.color_palette("pastel")

# 그래프 설정
fig = plt.figure(figsize=(25, 30))

# 1분기 그래프
ax1 = fig.add_subplot(2, 2, 1)
sns.barplot(data=df5, x='품목', y='합계', order=order_df5, palette=custom_palette)
ax1.set_title('1분기 품목별 합계', fontsize=20)
ax1.set_xlabel(' ')
ax1.set_ylabel('합계', fontsize=15)
plt.setp(ax1.xaxis.get_majorticklabels(), rotation=45, ha='right', rotation_mode='anchor', fontsize = 15)
plt.setp(ax1.yaxis.get_majorticklabels(),fontsize=20)
# 바 위에 수치 표시
for p in ax1.patches:
    ax1.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=15)
    
# 2분기 그래프
ax2 = fig.add_subplot(2, 2, 2)
sns.barplot(data=df6, x='품목', y='합계', order=order_df6, palette=custom_palette)
ax2.set_title('2분기 품목별 합계', fontsize=20)
ax2.set_xlabel(' ')
ax2.set_ylabel('합계', fontsize=15)
plt.setp(ax2.xaxis.get_majorticklabels(), rotation=45, ha='right', rotation_mode='anchor', fontsize = 15)
plt.setp(ax2.yaxis.get_majorticklabels(),fontsize=20)

# 바 위에 수치 표시
for p in ax2.patches:
    ax2.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=15)
    
# 3분기 그래프
ax3 = fig.add_subplot(2, 2, 3)
sns.barplot(data=df7, x='품목', y='합계', order=order_df7, palette=custom_palette)
ax3.set_title('3분기 품목별 합계', fontsize=20)
ax3.set_xlabel(' ')
ax3.set_ylabel('합계', fontsize=15)
plt.setp(ax3.xaxis.get_majorticklabels(), rotation=45, ha='right', rotation_mode='anchor', fontsize = 15)
plt.setp(ax3.yaxis.get_majorticklabels(),fontsize=20)

# 바 위에 수치 표시
for p in ax3.patches:
    ax3.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=15)

# 4분기 그래프
ax4 = fig.add_subplot(2, 2, 4)
sns.barplot(data=df8, x='품목', y='합계', order=order_df8, palette=custom_palette)
ax4.set_title('4분기 품목별 합계', fontsize=20)
ax4.set_xlabel(' ')
ax4.set_ylabel('합계', fontsize=15)
plt.setp(ax4.xaxis.get_majorticklabels(), rotation=45, ha='right', rotation_mode='anchor', fontsize = 15)
plt.setp(ax4.yaxis.get_majorticklabels(),fontsize=20)

# 바 위에 수치 표시
for p in ax4.patches:
    ax4.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=15)

# 전체 그래프의 제목
fig.suptitle('2018년도 분기별 선용품 품목', fontsize=30)

plt.show()

# %% [markdown]
# ## 2019년도 분석

# %%
# 파이썬 표시 깨짐 방지 하는 문구
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False 
f_path = "C:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname = f_path).get_name()
rc('font', family=font_name)

import pandas as pd
import seaborn as sns
import plotly.express as px
# 파일들 불러오기
df5 = pd.read_csv('../data/2019.1분기.csv')
df6 = pd.read_csv('../data/2019.2분기.csv')
df7 = pd.read_csv('../data/2019.3분기.csv')
df8 = pd.read_csv('../data/2019.4분기.csv')

df5.sort_values(by='합계', ascending=False, inplace = True)

# 그래프 x라벨값들 순서 통일
order_df5 = df5['품목'].unique()
order_df6 = df5['품목'].unique()
order_df7 = df5['품목'].unique()
order_df8 = df5['품목'].unique()

# 그래프 색상 설정
custom_palette = sns.color_palette("pastel")

# 그래프 설정
fig = plt.figure(figsize=(25, 30))

# 1분기 그래프
ax1 = fig.add_subplot(2, 2, 1)
sns.barplot(data=df5, x='품목', y='합계', order=order_df5, palette=custom_palette)
ax1.set_title('1분기 품목별 합계', fontsize=20)
ax1.set_xlabel(' ')
ax1.set_ylabel('합계', fontsize=15)
plt.setp(ax1.xaxis.get_majorticklabels(), rotation=45, ha='right', rotation_mode='anchor', fontsize = 15)
plt.setp(ax1.yaxis.get_majorticklabels(),fontsize=20)

# 바 위에 수치 표시
for p in ax1.patches:
    ax1.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=15)
    
# 2분기 그래프
ax2 = fig.add_subplot(2, 2, 2)
sns.barplot(data=df6, x='품목', y='합계', order=order_df6, palette=custom_palette)
ax2.set_title('2분기 품목별 합계', fontsize=20)
ax2.set_xlabel(' ')
ax2.set_ylabel('합계', fontsize=15)
plt.setp(ax2.xaxis.get_majorticklabels(), rotation=45, ha='right', rotation_mode='anchor', fontsize=15)
plt.setp(ax2.yaxis.get_majorticklabels(),fontsize=20)

# 바 위에 수치 표시
for p in ax2.patches:
    ax2.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=15)

# 3분기 그래프
ax3 = fig.add_subplot(2, 2, 3)
sns.barplot(data=df7, x='품목', y='합계', order=order_df7, palette=custom_palette)
ax3.set_title('3분기 품목별 합계', fontsize=20)
ax3.set_xlabel(' ')
ax3.set_ylabel('합계', fontsize=15)
plt.setp(ax3.xaxis.get_majorticklabels(), rotation=45, ha='right', rotation_mode='anchor', fontsize=15)
plt.setp(ax3.yaxis.get_majorticklabels(),fontsize=20)

# 바 위에 수치 표시
for p in ax3.patches:
    ax3.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=15)

# 4분기 그래프
ax4 = fig.add_subplot(2, 2, 4)
sns.barplot(data=df8, x='품목', y='합계', order=order_df8, palette=custom_palette)
ax4.set_title('4분기 품목별 합계', fontsize=20)
ax4.set_xlabel(' ')
ax4.set_ylabel('합계', fontsize=15)
plt.setp(ax4.xaxis.get_majorticklabels(), rotation=45, ha='right', rotation_mode='anchor', fontsize=15)
plt.setp(ax4.yaxis.get_majorticklabels(),fontsize=20)

# 바 위에 수치 표시
for p in ax4.patches:
    ax4.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=15)

# 전체 그래프의 제목
fig.suptitle('2019년도 분기별 선용품 품목', fontsize=30)

# HTML 파일로 저장
fig.savefig('2019년도 품목별 데이터')
plt.show()

# %% [markdown]
# ## 2020년도 분석

# %%
# 파이썬 표시 깨짐 방지 하는 문구
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False 
f_path = "C:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname = f_path).get_name()
rc('font', family=font_name)

import pandas as pd
import seaborn as sns
import plotly.express as px
# 파일들 불러오기
df5 = pd.read_csv('../data/2020.1분기.csv')
df6 = pd.read_csv('../data/2020.2분기.csv')
df7 = pd.read_csv('../data/2020.3분기.csv')
df8 = pd.read_csv('../data/2020.4분기.csv')

df5.sort_values(by='합계', ascending=False, inplace = True)
# 그래프 x라벨값들 순서 통일
order_df5 = df5['품목'].unique()
order_df6 = df5['품목'].unique()
order_df7 = df5['품목'].unique()
order_df8 = df5['품목'].unique()

# 그래프 색상 설정
custom_palette = sns.color_palette("pastel")

# 그래프 설정
fig = plt.figure(figsize=(25, 30))

# 1분기 그래프
ax1 = fig.add_subplot(2, 2, 1)
sns.barplot(data=df5, x='품목', y='합계', order=order_df5, palette=custom_palette)
ax1.set_title('1분기 품목별 합계', fontsize=20)
ax1.set_xlabel(' ')
ax1.set_ylabel('합계', fontsize=15)
plt.setp(ax1.xaxis.get_majorticklabels(), rotation=45, ha='right', rotation_mode='anchor', fontsize = 15)
plt.setp(ax1.yaxis.get_majorticklabels(),fontsize=20)

# 바 위에 수치 표시
for p in ax1.patches:
    ax1.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=15)

# 2분기 그래프
ax2 = fig.add_subplot(2, 2, 2)
sns.barplot(data=df6, x='품목', y='합계', order=order_df6, palette=custom_palette)
ax2.set_title('2분기 품목별 합계', fontsize=20)
ax2.set_xlabel(' ')
ax2.set_ylabel('합계', fontsize=15)
plt.setp(ax2.xaxis.get_majorticklabels(), rotation=45, ha='right', rotation_mode='anchor', fontsize=15)
plt.setp(ax2.yaxis.get_majorticklabels(),fontsize=20)

# 바 위에 수치 표시
for p in ax2.patches:
    ax2.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=15)


# 3분기 그래프
ax3 = fig.add_subplot(2, 2, 3)
sns.barplot(data=df7, x='품목', y='합계', order=order_df7, palette=custom_palette)
ax3.set_title('3분기 품목별 합계', fontsize=20)
ax3.set_xlabel(' ')
ax3.set_ylabel('합계', fontsize=15)
plt.setp(ax3.xaxis.get_majorticklabels(), rotation=45, ha='right', rotation_mode='anchor', fontsize=15)
plt.setp(ax3.yaxis.get_majorticklabels(),fontsize=20)

# 바 위에 수치 표시
for p in ax3.patches:
    ax3.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=15)

# 4분기 그래프
ax4 = fig.add_subplot(2, 2, 4)
sns.barplot(data=df8, x='품목', y='합계', order=order_df8, palette=custom_palette)
ax4.set_title('4분기 품목별 합계', fontsize=20)
ax4.set_xlabel(' ')
ax4.set_ylabel('합계', fontsize=15)
plt.setp(ax4.xaxis.get_majorticklabels(), rotation=45, ha='right', rotation_mode='anchor', fontsize=15)
plt.setp(ax4.yaxis.get_majorticklabels(),fontsize=20)

# 바 위에 수치 표시
for p in ax4.patches:
    ax4.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=15)

# 전체 그래프의 제목
fig.suptitle('2020년도 분기별 선용품 품목', fontsize=30)

# HTML 파일로 저장
fig.savefig('2020년도 품목별 데이터')
plt.show()

# %% [markdown]
# ## 2021년도 분석

# %%
# 파이썬 표시 깨짐 방지 하는 문구
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False 
f_path = "C:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname = f_path).get_name()
rc('font', family=font_name)

import pandas as pd
import seaborn as sns
import plotly.express as px
# 파일들 불러오기
df5 = pd.read_csv('../data/2021.1분기.csv')
df6 = pd.read_csv('../data/2021.2분기.csv')
df7 = pd.read_csv('../data/2021.3분기.csv')
df8 = pd.read_csv('../data/2021.4분기.csv')

df5.sort_values(by='합계', ascending=False, inplace = True)
# 그래프 x라벨값들 순서 통일
# 그래프 x라벨값들 순서 통일
order_df5 = df5['품목'].unique()
order_df6 = df5['품목'].unique()
order_df7 = df5['품목'].unique()
order_df8 = df5['품목'].unique()

# 그래프 색상 설정
custom_palette = sns.color_palette("pastel")

# 그래프 설정
fig = plt.figure(figsize=(25, 30))

# 1분기 그래프
ax1 = fig.add_subplot(2, 2, 1)
sns.barplot(data=df5, x='품목', y='합계', order=order_df5, palette=custom_palette)
ax1.set_title('1분기 품목별 합계', fontsize=20)
ax1.set_xlabel(' ')
ax1.set_ylabel('합계', fontsize=15)
plt.setp(ax1.xaxis.get_majorticklabels(), rotation=45, ha='right', rotation_mode='anchor', fontsize = 15)
plt.setp(ax1.yaxis.get_majorticklabels(),fontsize=20)

# 바 위에 수치 표시
for p in ax1.patches:
    ax1.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=15)

# 2분기 그래프
ax2 = fig.add_subplot(2, 2, 2)
sns.barplot(data=df6, x='품목', y='합계', order=order_df6, palette=custom_palette)
ax2.set_title('2분기 품목별 합계', fontsize=20)
ax2.set_xlabel(' ')
ax2.set_ylabel('합계', fontsize=15)
plt.setp(ax2.xaxis.get_majorticklabels(), rotation=45, ha='right', rotation_mode='anchor', fontsize=15)
plt.setp(ax2.yaxis.get_majorticklabels(),fontsize=20)

# 바 위에 수치 표시
for p in ax2.patches:
    ax2.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=15)


# 3분기 그래프
ax3 = fig.add_subplot(2, 2, 3)
sns.barplot(data=df7, x='품목', y='합계', order=order_df7, palette=custom_palette)
ax3.set_title('3분기 품목별 합계', fontsize=20)
ax3.set_xlabel(' ')
ax3.set_ylabel('합계', fontsize=15)
plt.setp(ax3.xaxis.get_majorticklabels(), rotation=45, ha='right', rotation_mode='anchor', fontsize=15)
plt.setp(ax3.yaxis.get_majorticklabels(),fontsize=20)

# 바 위에 수치 표시
for p in ax3.patches:
    ax3.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=15)

# 4분기 그래프
ax4 = fig.add_subplot(2, 2, 4)
sns.barplot(data=df8, x='품목', y='합계', order=order_df8, palette=custom_palette)
ax4.set_title('4분기 품목별 합계', fontsize=20)
ax4.set_xlabel(' ')
ax4.set_ylabel('합계', fontsize=15)
plt.setp(ax4.xaxis.get_majorticklabels(), rotation=45, ha='right', rotation_mode='anchor', fontsize=15)
plt.setp(ax4.yaxis.get_majorticklabels(),fontsize=20)

# 바 위에 수치 표시
for p in ax4.patches:
    ax4.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=15)

# 전체 그래프의 제목
fig.suptitle('2021년도 분기별 선용품 품목', fontsize=30)

# HTML 파일로 저장
fig.savefig('2021년도 품목별 데이터')
plt.show()

# %% [markdown]
# ## 2022년도 분석

# %%
# 파이썬 표시 깨짐 방지 하는 문구
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False 
f_path = "C:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname = f_path).get_name()
rc('font', family=font_name)

import pandas as pd
import seaborn as sns
import plotly.express as px
# 파일들 불러오기
df5 = pd.read_csv('../data/2022.1분기.csv')
df6 = pd.read_csv('../data/2022.2분기.csv')
df7 = pd.read_csv('../data/2022.3분기.csv')
df8 = pd.read_csv('../data/2022.4분기.csv')

df5.sort_values(by='합계', ascending=False, inplace = True)
# 그래프 x라벨값들 순서 통일
order_df5 = df5['품목'].unique()
order_df6 = df5['품목'].unique()
order_df7 = df5['품목'].unique()
order_df8 = df5['품목'].unique()

# 그래프 색상 설정
custom_palette = sns.color_palette("pastel")

# 그래프 설정
fig = plt.figure(figsize=(25, 30))

# 1분기 그래프
ax1 = fig.add_subplot(2, 2, 1)
sns.barplot(data=df5, x='품목', y='합계', order=order_df5, palette=custom_palette)
ax1.set_title('1분기 품목별 합계', fontsize=20)
ax1.set_xlabel(' ')
ax1.set_ylabel('합계', fontsize=15)
plt.setp(ax1.xaxis.get_majorticklabels(), rotation=45, ha='right', rotation_mode='anchor', fontsize = 15)
plt.setp(ax1.yaxis.get_majorticklabels(),fontsize=20)

# 바 위에 수치 표시
for p in ax1.patches:
    ax1.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=15)

# 2분기 그래프
ax2 = fig.add_subplot(2, 2, 2)
sns.barplot(data=df6, x='품목', y='합계', order=order_df6, palette=custom_palette)
ax2.set_title('2분기 품목별 합계', fontsize=20)
ax2.set_xlabel(' ')
ax2.set_ylabel('합계', fontsize=15)
plt.setp(ax2.xaxis.get_majorticklabels(), rotation=45, ha='right', rotation_mode='anchor', fontsize=15)
plt.setp(ax2.yaxis.get_majorticklabels(),fontsize=20)

# 바 위에 수치 표시
for p in ax2.patches:
    ax2.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=15)


# 3분기 그래프
ax3 = fig.add_subplot(2, 2, 3)
sns.barplot(data=df7, x='품목', y='합계', order=order_df7, palette=custom_palette)
ax3.set_title('3분기 품목별 합계', fontsize=20)
ax3.set_xlabel(' ')
ax3.set_ylabel('합계', fontsize=15)
plt.setp(ax3.xaxis.get_majorticklabels(), rotation=45, ha='right', rotation_mode='anchor', fontsize=15)
plt.setp(ax3.yaxis.get_majorticklabels(),fontsize=20)

# 바 위에 수치 표시
for p in ax3.patches:
    ax3.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=15)

# 4분기 그래프
ax4 = fig.add_subplot(2, 2, 4)
sns.barplot(data=df8, x='품목', y='합계', order=order_df8, palette=custom_palette)
ax4.set_title('4분기 품목별 합계', fontsize=20)
ax4.set_xlabel(' ')
ax4.set_ylabel('합계', fontsize=15)
plt.setp(ax4.xaxis.get_majorticklabels(), rotation=45, ha='right', rotation_mode='anchor', fontsize=15)
plt.setp(ax4.yaxis.get_majorticklabels(),fontsize=20)

# 바 위에 수치 표시
for p in ax4.patches:
    ax4.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=15)

# 전체 그래프의 제목
fig.suptitle('2022년도 분기별 선용품 품목', fontsize=30)

# HTML 파일로 저장
fig.savefig('2022년도 품목별 데이터')
plt.show()

# %% [markdown]
# ## 2023년도 분석

# %%
# 파이썬 표시 깨짐 방지 하는 문구
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False 
f_path = "C:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname = f_path).get_name()
rc('font', family=font_name)

import pandas as pd
import seaborn as sns
import plotly.express as px
# 파일들 불러오기
df5 = pd.read_csv('../data/2023.1분기.csv')
df6 = pd.read_csv('../data/2023.2분기.csv')
df7 = pd.read_csv('../data/2023.3분기.csv')
df8 = pd.read_csv('../data/2023.4분기.csv')

df5.sort_values(by='합계', ascending=False, inplace = True)
# 그래프 x라벨값들 순서 통일
order_df5 = df5['품목'].unique()
order_df6 = df5['품목'].unique()
order_df7 = df5['품목'].unique()
order_df8 = df5['품목'].unique()

# 그래프 색상 설정
custom_palette = sns.color_palette("pastel")

# 그래프 설정
fig = plt.figure(figsize=(25, 30))

# 1분기 그래프
ax1 = fig.add_subplot(2, 2, 1)
sns.barplot(data=df5, x='품목', y='합계', order=order_df5, palette=custom_palette)
ax1.set_title('1분기 품목별 합계', fontsize=20)
ax1.set_xlabel(' ')
ax1.set_ylabel('합계', fontsize=15)
plt.setp(ax1.xaxis.get_majorticklabels(), rotation=45, ha='right', rotation_mode='anchor', fontsize = 15)
plt.setp(ax1.yaxis.get_majorticklabels(),fontsize=20)

# 바 위에 수치 표시
for p in ax1.patches:
    ax1.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=15)

# 2분기 그래프
ax2 = fig.add_subplot(2, 2, 2)
sns.barplot(data=df6, x='품목', y='합계', order=order_df6, palette=custom_palette)
ax2.set_title('2분기 품목별 합계', fontsize=20)
ax2.set_xlabel(' ')
ax2.set_ylabel('합계', fontsize=15)
plt.setp(ax2.xaxis.get_majorticklabels(), rotation=45, ha='right', rotation_mode='anchor', fontsize=15)
plt.setp(ax2.yaxis.get_majorticklabels(),fontsize=20)

# 바 위에 수치 표시
for p in ax2.patches:
    ax2.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=15)


# 3분기 그래프
ax3 = fig.add_subplot(2, 2, 3)
sns.barplot(data=df7, x='품목', y='합계', order=order_df7, palette=custom_palette)
ax3.set_title('3분기 품목별 합계', fontsize=20)
ax3.set_xlabel(' ')
ax3.set_ylabel('합계', fontsize=15)
plt.setp(ax3.xaxis.get_majorticklabels(), rotation=45, ha='right', rotation_mode='anchor', fontsize=15)
plt.setp(ax3.yaxis.get_majorticklabels(),fontsize=20)

# 바 위에 수치 표시
for p in ax3.patches:
    ax3.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=15)

# 4분기 그래프
ax4 = fig.add_subplot(2, 2, 4)
sns.barplot(data=df8, x='품목', y='합계', order=order_df8, palette=custom_palette)
ax4.set_title('4분기 품목별 합계', fontsize=20)
ax4.set_xlabel(' ')
ax4.set_ylabel('합계', fontsize=15)
plt.setp(ax4.xaxis.get_majorticklabels(), rotation=45, ha='right', rotation_mode='anchor', fontsize=15)
plt.setp(ax4.yaxis.get_majorticklabels(),fontsize=20)

# 바 위에 수치 표시
for p in ax4.patches:
    ax4.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=15)

# 전체 그래프의 제목
fig.suptitle('2023년도 분기별 선용품 품목', fontsize=30)

# HTML 파일로 저장
fig.savefig('2023년도 품목별 데이터')
plt.show()
